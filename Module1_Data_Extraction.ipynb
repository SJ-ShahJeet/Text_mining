# %%
import requests
import pandas as pd

# %%
NEWS_API_KEY = "0e277916b348424ea9987d075aafc078"

BASE_URL = "https://newsapi.org/v2/everything"

params = {
    "q": "single-use plastics",
    "language": "en",
    "sortBy": "relevancy",
    "pageSize": 100,  
    "apiKey": NEWS_API_KEY
}

# %%
def fetch_news():
    all_articles = []
    page = 1

    while True:
        params["page"] = page
        response = requests.get(BASE_URL, params=params)

        if response.status_code == 200:
            data = response.json()
            if not data["articles"]:
                break

            for article in data["articles"]:
                all_articles.append([
                    article["source"]["name"],
                    article["title"],
                    article["description"],
                    article["content"],
                    article["url"],
                    article["publishedAt"]
                ])
            
            page += 1
        else:
            break

    df = pd.DataFrame(all_articles, columns=["Source", "Title", "Description", "Content", "URL", "PublishedAt"])
    df.drop_duplicates(subset=["Title", "URL"], inplace=True)
    df.to_csv("newsapi_articles.csv", index=False)

fetch_news()

# %%
GUARDIAN_API_KEY = "4c92f442-7867-4178-ad0a-f11f2b9d6a4e"


GUARDIAN_BASE_URL = "https://content.guardianapis.com/search"


guardian_params = {
    "q": "single-use plastics",
    "section": "environment",
    "page-size": 50,  # Max per request
    "order-by": "relevance",
    "show-fields": "headline,bodyText,shortUrl",
    "api-key": GUARDIAN_API_KEY
}

# %%
def fetch_guardian_news():
    all_articles = []
    page = 1

    while True:
        guardian_params["page"] = page
        response = requests.get(GUARDIAN_BASE_URL, params=guardian_params)

        if response.status_code == 200:
            data = response.json()
            results = data["response"]["results"]
            
            if not results:
                break

            for article in results:
                all_articles.append([
                    article["webPublicationDate"],
                    article["sectionName"],
                    article["fields"]["headline"],
                    article["fields"]["bodyText"],
                    article["fields"]["shortUrl"]
                ])
            
            page += 1
        else:
            break

    df = pd.DataFrame(all_articles, columns=["PublishedAt", "Section", "Title", "Content", "URL"])
    df.drop_duplicates(subset=["Title", "URL"], inplace=True)
    df.to_csv("guardian_articles.csv", index=False)

fetch_guardian_news()

# %%
import requests
import json

newsapi_url = "https://newsapi.org/v2/everything?q=single-use+plastics&apiKey=0e277916b348424ea9987d075aafc078"
guardian_url = "https://content.guardianapis.com/search?q=plastic&tag=environment/environment&api-key=4c92f442-7867-4178-ad0a-f11f2b9d6a4e"


def fetch_api_data(api_url):
    response = requests.get(api_url)
    if response.status_code == 200:
        data = response.json()  
        print(json.dumps(data, indent=4))  
    else:
        print(f"Error: Unable to fetch data. Status Code: {response.status_code}")


print("NewsAPI JSON Response:")
fetch_api_data(newsapi_url)
# Out:
# NewsAPI JSON Response:
# {
#     "status": "ok",
#     "totalResults": 255,
#     "articles": [
#         {
#             "source": {
#                 "id": null,
#                 "name": "Hackaday"
#             },
#             "author": "Maya Posch",
#             "title": "Plastic On The Mind: Assessing the Risks From Micro- and Nanoplastics",
#             "description": "Perhaps one of the clearest indications of the Anthropocene may be the presence of plastic. Starting with the commercialization of Bakelite in 1907 by Leo Baekeland, plastics have taken the \u2026read more",
#             "url": "https://hackaday.com/2025/02/12/plastic-on-the-mind-assessing-the-risks-from-micro-and-nanoplastics/",
#             "urlToImage": "https://hackaday.com/wp-content/uploads/2025/02/Plastics.jpg",
#             "publishedAt": "2025-02-12T15:00:32Z",
#             "content": "Perhaps one of the clearest indications of the Anthropocene may be the presence of plastic. Starting with the commercialization of Bakelite in 1907 by Leo Baekeland, plastics have taken the world by \u2026 [+10938 chars]"
#         },
#         {
#             "source": {
#                 "id": null,
#                 "name": "BBC News"
#             },
#             "author": null,
#             "title": "Scenic loch becomes magnet for Scotland's plastic waste",
#             "description": "One of Scotland's biggest plastic problems, the Arrochar litter sink, sits at the head of the scenic loch.",
#             "url": "https://www.bbc.com/news/articles/cp8256l20l0o",
#             "urlToImage": "https://ichef.bbci.co.uk/news/1024/branded_news/3a43/live/84e34bb0-dfe8-11ef-9db5-61a9bc752e71.jpg",
#             "publishedAt": "2025-02-03T00:53:58Z",
#             "content": "Kevin KeaneBBC Scotland's environment correspondent\r\nThe banks of Loch Long at Arrochar are strewn with plastics from the River Clyde\r\nAt the head of beautiful Loch Long in Argyll sits one of Scotlan\u2026 [+4912 chars]"
#         },
#         {
#             "source": {
#                 "id": null,
#                 "name": "Yahoo Entertainment"
#             },
#             "author": "Reuters",
#             "title": "Trump rolls back standards for water-using appliances, light bulbs",
#             "description": "WASHINGTON (Reuters) -President Donald Trump on Tuesday moved to revert to older standards for light bulbs as well as toilets, showers and other water-using ...",
#             "url": "https://ca.finance.yahoo.com/news/trump-roll-back-appliance-light-122050090.html",
#             "urlToImage": "https://media.zenfs.com/en/reuters.com/8522a482d08b1796ab12ee90dd017c31",
#             "publishedAt": "2025-02-11T12:20:50Z",
#             "content": "WASHINGTON (Reuters) -President Donald Trump on Tuesday moved to revert to older standards for light bulbs as well as toilets, showers and other water-using appliances, a day after signing an order p\u2026 [+1123 chars]"
#         },
#         {
#             "source": {
#                 "id": null,
#                 "name": "Scientific American"
#             },
#             "author": "Megha Satyanarayana",
#             "title": "Why Aren\u2019t We Losing Our Minds Over the Plastic in Our Brains?",
#             "description": "New research on microplastics in brains reminds us that while scientists compile safety data, our leaders should still act",
#             "url": "https://www.scientificamerican.com/article/why-arent-we-losing-our-minds-over-the-plastic-in-our-brains/",
#             "urlToImage": "https://static.scientificamerican.com/dam/m/599b3b93a5d5e846/original/Microplastics-in-petri-dish.jpg?m=1739497543.721&w=1200",
#             "publishedAt": "2025-02-14T12:00:00Z",
#             "content": "Our brains are full of plastic.\r\nThis was the fun news I read earlier this week while picking up dinner take-out, packed in plastic containers, crammed in a plastic bag and accompanied by Styrofoam c\u2026 [+7211 chars]"
#         },
#         {
#             "source": {
#                 "id": "buzzfeed",
#                 "name": "Buzzfeed"
#             },
#             "author": "Elizabeth Lilly",
#             "title": "36 Products That\u2019ll Help Get You Through TSA Faster In 2025",
#             "description": "You can pick up your Security Pro merit badge after you collect your baggage on the belt.View Entire Post \u203a",
#             "url": "https://www.buzzfeed.com/elizabethlilly/products-help-get-through-tsa-airport-faster-2025-an",
#             "urlToImage": "https://img.buzzfeed.com/buzzfeed-static/static/2025-01/22/4/campaign_images/46eeba04b494/36-products-thatll-help-get-you-through-tsa-faste-2-2056-1737519946-0_dblbig.jpg",
#             "publishedAt": "2025-02-04T13:31:02Z",
#             "content": "Cadence is an AAPI woman-owned small business that was founded by Steph Hon as a way to eliminate single-use travel-sized plastics. The containers are made from recycled ocean-bound plastic.\u00a0\r\nBut I'\u2026 [+1559 chars]"
#         },
#         {
#             "source": {
#                 "id": null,
#                 "name": "Forbes"
#             },
#             "author": "Jamie Hailstone, Contributor, \n Jamie Hailstone, Contributor\n https://www.forbes.com/sites/jamiehailstone/",
#             "title": "Do American Voters Want To See More Single-Use Plastic Or Less?",
#             "description": "Oceana\u2019s U.S. plastics campaign director, Christy Leavitt said President Trump is \u201cgoing in the wrong direction on single-use plastics\u201d.",
#             "url": "https://www.forbes.com/sites/jamiehailstone/2025/02/13/do-american-voters-want-to-see-more-single-use-plastic-or-less/",
#             "urlToImage": "https://imageio.forbes.com/specials-images/imageserve/67add428b56add68171abb66/0x0.jpg?format=jpg&height=900&width=1600&fit=bounds",
#             "publishedAt": "2025-02-13T11:24:49Z",
#             "content": "WASHINGTON, DC - FEBRUARY 10: U.S. President Donald Trump reacts to a question from a reporter after ... [+] signing a series of executive orders including 25% tariffs on steel and aluminum, a pardon\u2026 [+4123 chars]"
#         },
#         {
#             "source": {
#                 "id": null,
#                 "name": "BBC News"
#             },
#             "author": null,
#             "title": "Trump signs order shifting US back toward plastic straws",
#             "description": "The president has long been a critic of paper straws, which he says don't work and dissolve too easily.",
#             "url": "https://www.bbc.com/news/articles/c2k574ydyyqo",
#             "urlToImage": "https://ichef.bbci.co.uk/news/1024/branded_news/03e8/live/4a7e7b50-e7d8-11ef-8295-1f3717f0b004.jpg",
#             "publishedAt": "2025-02-11T01:30:24Z",
#             "content": "Bernd Debusmann JrReporting from\r\nWhite House\r\nUS President Donald Trump has signed an executive order ending a US government effort to replace plastic straws with paper. \r\nThe order, which takes eff\u2026 [+2377 chars]"
#         },
#         {
#             "source": {
#                 "id": null,
#                 "name": "Mental Floss"
#             },
#             "author": "CaLea Johnson",
#             "title": "You Can Earn $1500 For Organizing Your Kitchen",
#             "description": "If you resolved to organize your kitchen in 2025, this contest is pretty good motivation.",
#             "url": "https://www.mentalfloss.com/earn-money-for-organizing-your-kitchen",
#             "urlToImage": "https://images2.minutemediacdn.com/image/upload/c_crop,w_2000,h_1125,x_0,y_0/v1737063882/images/voltaxMediaLibrary/mmsport/mentalfloss/01jhrh6psgpwfx9jpmps.jpg",
#             "publishedAt": "2025-01-17T16:01:00Z",
#             "content": "Although the origins of New Years resolutions date back to ancient times, the tradition is still going strong. Year after year, people vow to make massive changes in their lives, whether its spending\u2026 [+1811 chars]"
#         },
#         {
#             "source": {
#                 "id": "cbc-news",
#                 "name": "CBC News"
#             },
#             "author": null,
#             "title": "Trump signs order to buy plastic straws, eliminate paper straws",
#             "description": "U.S. President Donald Trump has signed an executive order aimed at encouraging the U.S. government and consumers to buy plastic drinking straws, pushing back efforts by his predecessor to phase out single-use plastics and tackle waste.",
#             "url": "https://www.cbc.ca/news/science/trump-plastic-straws-1.7455862",
#             "urlToImage": "https://i.cbc.ca/1.7310600.1725632745!/cumulusImage/httpImage/image.jpg_gen/derivatives/16x9_1180/single-use-plastic-ban-vancouver-straws.jpg?im=Resize%3D620",
#             "publishedAt": "2025-02-11T13:53:08Z",
#             "content": "U.S. President Donald Trump on Monday signed an executive order aimed at encouraging the U.S. government and consumers to buy plastic drinking straws, pushing back efforts by his predecessor to phase\u2026 [+3213 chars]"
#         },
#         {
#             "source": {
#                 "id": null,
#                 "name": "Hackaday"
#             },
#             "author": "Lewin Day",
#             "title": "How Do We Deal With Microplastics In The Ocean?",
#             "description": "Like the lead paint and asbestos of decades past, microplastics are the new awful contaminant that we really ought to do something about. They\u2019re particularly abundant in the aquatic environment, \u2026read more",
#             "url": "https://hackaday.com/2025/02/06/how-do-we-deal-with-microplastics-in-the-ocean/",
#             "urlToImage": "https://hackaday.com/wp-content/uploads/2025/01/microplastics_21282786668_2ce70ca17c_k.jpg",
#             "publishedAt": "2025-02-06T15:00:19Z",
#             "content": "Like the lead paint and asbestos of decades past, microplastics are the new awful contaminant that we really ought to do something about. They\u2019re particularly abundant in the aquatic environment, and\u2026 [+4633 chars]"
#         },
#         {
#             "source": {
#                 "id": null,
#                 "name": "Mental Floss"
#             },
#             "author": "CaLea Johnson",
#             "title": "Get Paid $1000 to Taste-Test Costco\u2018s Best Game Day Snacks",
#             "description": "If you were already planning to eat Costco snacks during the big game, now you can get paid for your trouble.",
#             "url": "https://www.mentalfloss.com/get-paid-to-test-costco-snacks",
#             "urlToImage": "https://images2.minutemediacdn.com/image/upload/c_crop,w_5616,h_3159,x_0,y_418/images/GettyImages/mmsport/mentalfloss/01jj7bxh9axsjshwzgya",
#             "publishedAt": "2025-01-23T14:01:00Z",
#             "content": "Whether you want to quit social media or get rid of single-use plastics in your house, theres a company out there willing to pay you for your trouble. FinanceBuzz is the latest brand offering a cash \u2026 [+1609 chars]"
#         },
#         {
#             "source": {
#                 "id": null,
#                 "name": "Windows Central"
#             },
#             "author": "richard.devine@futurenet.com (Richard Devine)",
#             "title": "First the EU came for the iPhone charging port, now it's coming for unnecessary CPU packaging \u2014 stock coolers may be a thing of the past",
#             "description": "Recently passed legislation gives an 18-month grace period but after that, all products in all sectors will need lesser, and more sustainable packaging",
#             "url": "https://www.windowscentral.com/hardware/first-the-eu-came-for-the-iphone-charging-port-now-its-coming-for-unnecessary-cpu-packaging",
#             "urlToImage": "https://cdn.mos.cms.futurecdn.net/fEn6eYdUFdFR2QuSxKwVD4-1200-80.jpg",
#             "publishedAt": "2025-02-13T15:23:34Z",
#             "content": "Ah, EU regulations. Some love them, some, namely non-EU countries and businesses, tend to loathe them. Nevertheless, they exist, and the latest one will affect, among other products, those wonderful \u2026 [+2362 chars]"
#         },
#         {
#             "source": {
#                 "id": null,
#                 "name": "Makezine.com"
#             },
#             "author": "Ryan Priore",
#             "title": "Laser Eye Safety in Digital Fabrication: Protecting Your Vision",
#             "description": "Safeguard your vision while working with laser tooling so you can unleash your creative potential.\nThe post Laser Eye Safety in Digital Fabrication: Protecting Your Vision appeared first on Make: DIY Projects and Ideas for Makers.",
#             "url": "https://makezine.com/article/digital-fabrication/laser-cutting-digital-fabrication/laser-eye-safety-in-digital-fabrication-protecting-your-vision/",
#             "urlToImage": "https://makezine.com/wp-content/uploads/2025/02/Laser-Eye-Safety-glasses.jpg",
#             "publishedAt": "2025-02-08T01:42:03Z",
#             "content": "Disclaimer: This article is not an official training or certification for laser safety. You are responsible for the safety of yourself and others while you are operating a laser cutter or engraver.\r\n\u2026 [+21288 chars]"
#         },
#         {
#             "source": {
#                 "id": null,
#                 "name": "Yanko Design"
#             },
#             "author": "Srishti Mitra",
#             "title": "10 Best Products To Integrate Sustainable Practices Into Your Home & Lifestyle",
#             "description": "10 Best Products To Integrate Sustainable Practices Into Your Home & LifestyleAs awareness of environmental impact grows, more individuals are seeking ways to incorporate sustainable practices into their everyday lives. One of the most effective places...",
#             "url": "https://www.yankodesign.com/2025/02/12/10-best-products-to-integrate-sustainable-practices-into-your-home-lifestyle/",
#             "urlToImage": "https://www.yankodesign.com/images/design_news/2025/02/10-best-products-to-integrate-sustainable-practices-into-your-home/top_10_products_sustainable_practice_yanko_design_01.jpg",
#             "publishedAt": "2025-02-12T12:40:43Z",
#             "content": "As awareness of environmental impact grows, more individuals are seeking ways to incorporate sustainable practices into their everyday lives. One of the most effective places to start is right at hom\u2026 [+15790 chars]"
#         },
#         {
#             "source": {
#                 "id": null,
#                 "name": "Forbes"
#             },
#             "author": "Michelle Greenwald, Contributor, \n Michelle Greenwald, Contributor\n https://www.forbes.com/sites/michellegreenwald/",
#             "title": "Two Of The Biggest 2025 Product Claims Will Be Plastic & Toxin Free",
#             "description": "Plastic free, toxin free, BPA Free will be among the top product claims in 2025 and beyond due to rising consumer concern with micro-plastics & black plastic kitchenware.",
#             "url": "https://www.forbes.com/sites/michellegreenwald/2025/01/17/two-of-2025s-most-important-new-product-claims-plastic-and-toxin-free/",
#             "urlToImage": "https://imageio.forbes.com/specials-images/imageserve/678a1725d1e3802909e83ccf/0x0.jpg?format=jpg&height=900&width=1600&fit=bounds",
#             "publishedAt": "2025-01-17T08:48:00Z",
#             "content": "Website home page for The Tribalist personal healthy home consultants\r\nThe Tribalist\r\nPlastic free and toxin free will be among the most compelling product claims in 2025 and beyond. Two large, growi\u2026 [+5317 chars]"
#         },
#         {
#             "source": {
#                 "id": null,
#                 "name": "Forbes"
#             },
#             "author": "Wayne Winegarden, Contributor, \n Wayne Winegarden, Contributor\n https://www.forbes.com/sites/waynewinegarden/",
#             "title": "California\u2019s Rash Plastic Lawsuit Is Anti-Growth And Anti-Environment",
#             "description": "The California AG's plastic lawsuit harms consumers, discourages growth & innovation, and obstructs the creative process necessary to address the plastic waste problem.",
#             "url": "https://www.forbes.com/sites/waynewinegarden/2025/02/10/californias-rash-plastic-lawsuit-is-anti-growth-and-anti-environment/",
#             "urlToImage": "https://imageio.forbes.com/specials-images/imageserve/67aa6ffe93721c5465f30a44/0x0.jpg?format=jpg&height=900&width=1600&fit=bounds",
#             "publishedAt": "2025-02-10T21:59:48Z",
#             "content": "Mobius loop or recycling symbol with arrows. \r\ngetty\r\nCalifornia Attorney General Rob Bontas plastics lawsuit against ExxonMobil may be astute politics but it is terrible policy. This lawsuit is rife\u2026 [+4500 chars]"
#         },
#         {
#             "source": {
#                 "id": null,
#                 "name": "Forbes"
#             },
#             "author": "Monica Sanders, Contributor, \n Monica Sanders, Contributor\n https://www.forbes.com/sites/monicasanders/",
#             "title": "How America Became The World\u2019s Trash Leader",
#             "description": "America leads the world in producing more trash than it knows what do with \u2014 running out of landfills by 2036.",
#             "url": "https://www.forbes.com/sites/monicasanders/2025/01/28/how-america-became-the-worlds-trash-leader/",
#             "urlToImage": "https://imageio.forbes.com/specials-images/imageserve/6796818f517fdb97188aeb10/0x0.jpg?format=jpg&height=900&width=1600&fit=bounds",
#             "publishedAt": "2025-01-28T15:00:00Z",
#             "content": "Piles of trash at a dump in Denver.\r\ngetty\r\nEvery second, Americans throw away enough trash to fill three Empire State Buildings. The United States has earned the dubious distinction of being the wor\u2026 [+7755 chars]"
#         },
#         {
#             "source": {
#                 "id": null,
#                 "name": "Grist"
#             },
#             "author": "Joseph Winters",
#             "title": "The \u2018recycled\u2019 plastic in your shoes, shirts, and bags? It\u2019s still destined for the landfill.",
#             "description": "Here\u2019s why that matters.",
#             "url": "http://grist.org/accountability/the-recycled-plastic-in-your-shoes-shirts-and-bags-its-still-destined-for-the-landfill/",
#             "urlToImage": "https://grist.org/wp-content/uploads/2025/02/DefinitionRecyclingThumbStill.jpg?quality=75&strip=all",
#             "publishedAt": "2025-02-05T09:45:00Z",
#             "content": "This story was produced by Grist and co-published with Teen Vogue.\r\nIn Seattle, as in most cities around the country, there are a number of items that you arent supposed to put in the curbside recycl\u2026 [+21131 chars]"
#         },
#         {
#             "source": {
#                 "id": null,
#                 "name": "Substack.com"
#             },
#             "author": "lcamtuf",
#             "title": "A brief history of counting machines (2023)",
#             "description": "A heterodox take on the prehistory, the golden years, and the future of general-purpose calculating aids.",
#             "url": "https://lcamtuf.substack.com/p/a-brief-history-of-counting-stuff",
#             "urlToImage": "https://substackcdn.com/image/fetch/w_1200,h_600,c_fill,f_jpg,q_auto:good,fl_progressive:steep,g_auto/https%3A%2F%2Fsubstack-post-media.s3.amazonaws.com%2Fpublic%2Fimages%2F1ca07078-2ebe-4538-8792-3390559450a2_1600x1068.jpeg",
#             "publishedAt": "2025-01-31T15:48:08Z",
#             "content": "I find it difficult to talk about the history of the computer. The actual record is dreadfully short: almost nothing of consequence happened before the year 1935. We keep looking for a better story, \u2026 [+13156 chars]"
#         },
#         {
#             "source": {
#                 "id": null,
#                 "name": "mindbodygreen.com"
#             },
#             "author": "https://www.mindbodygreen.com/wc/ava-durgin-writer",
#             "title": "Are Microplastics The Next Big Threat To Heart Health? Here\u2019s What Science Says",
#             "description": "Plus, 5 ways to decrease your exposure",
#             "url": "https://www.mindbodygreen.com/articles/plastic-in-arteries-research-links-microplastic-to-heart-disease",
#             "urlToImage": "https://mindbodygreen-res.cloudinary.com/image/upload/c_fill,w_2000,h_1200,g_auto,fl_lossy,f_jpg/org/wsit0hrsom72haq8r.jpeg",
#             "publishedAt": "2025-02-13T10:09:00Z",
#             "content": "Theyre in our oceans, our food, and nowpossiblyin our arteries.\u00a0\r\nA groundbreaking study1\r\npublished in The New England Journal of Medicine reveals a troubling link between microplastics and heart he\u2026 [+3194 chars]"
#         },
#         {
#             "source": {
#                 "id": null,
#                 "name": "The New Republic"
#             },
#             "author": "Edith Olmsted",
#             "title": "Trump Just Banned Paper Straws Because They Can \u201cExplode\u201d",
#             "description": "Donald Trump signed an executive order Monday liberating Americans from the \u201cforced use\u201d of paper straws, because why govern when you can just screw around? \r\nThe executive order stated that it would end the \u201cirrational campaign\u201d against plastic straws, and d\u2026",
#             "url": "https://newrepublic.com/post/191396/donald-trump-banned-paper-straws-reason",
#             "urlToImage": "https://images.newrepublic.com/bba4d4c336aa9b5ef6bd41dd0cf45c0bd383a651.jpeg?w=1200&h=630&crop=faces&fit=crop&fm=jpg",
#             "publishedAt": "2025-02-11T16:43:03Z",
#             "content": "The Baltimore-based Black Engineer of the Year Awards (BEYA) has historically been a key event for the Pentagon to recruit high-caliber STEM talent. One Army recruiter told the servicemember news out\u2026 [+895 chars]"
#         },
#         {
#             "source": {
#                 "id": null,
#                 "name": "NPR"
#             },
#             "author": "Jacob Fenston",
#             "title": "Trump says 'we're going back to plastic straws.' Is the paper straw dead?",
#             "description": "President Trump has signed an executive order decrying the \"irrational campaign against plastic straws\" and directing federal agencies to stop buying paper straws.",
#             "url": "https://www.npr.org/2025/02/11/nx-s1-5292234/trump-paper-straws-plastic-executive-order",
#             "urlToImage": "https://npr.brightspotcdn.com/dims3/default/strip/false/crop/3000x1688+0+156/resize/1400/quality/100/format/jpeg/?url=http%3A%2F%2Fnpr-brightspot.s3.amazonaws.com%2Fda%2F2a%2Fe0842a6448b5862d775066c7988b%2Fgettyimages-980583366.jpg",
#             "publishedAt": "2025-02-11T21:36:27Z",
#             "content": "A decade ago, a video of a sea turtle with a plastic straw stuck in its nostril went viral, spurring a wave of activism aimed at curtailing plastic pollution. The disposable plastic straw became the \u2026 [+3736 chars]"
#         },
#         {
#             "source": {
#                 "id": null,
#                 "name": "Forbes"
#             },
#             "author": "Mary Whitfill Roeloffs, Forbes Staff, \n Mary Whitfill Roeloffs, Forbes Staff\n https://www.forbes.com/sites/maryroeloffs/",
#             "title": "Trump Promises Executive Order Against Paper Straws: 'BACK TO PLASTIC!'",
#             "description": "President Donald Trump\u2019s campaign previously sold Trump-branded plastic straws with the message, \u201cLiberal paper straws don't work.\u201d",
#             "url": "https://www.forbes.com/sites/maryroeloffs/2025/02/07/trump-promises-executive-order-against-paper-straws-back-to-plastic/",
#             "urlToImage": "https://imageio.forbes.com/specials-images/imageserve/67a63dbe9339e7f171b0ebae/0x0.jpg?format=jpg&crop=2543,1429,x133,y84,safe&height=900&width=1600&fit=bounds",
#             "publishedAt": "2025-02-07T17:20:49Z",
#             "content": "President Donald Trump has said he will end what he called a ridiculous Biden-era push to phase out single-use plastics in federal agencies by 2035 in efforts to combat plastic pollution, claiming in\u2026 [+4569 chars]"
#         },
#         {
#             "source": {
#                 "id": null,
#                 "name": "Bringatrailer.com"
#             },
#             "author": "bringatrailer",
#             "title": "1983 Husqvarna 430 WR at No Reserve",
#             "description": "This 1983 Husqvarna 430 WR was acquired by the seller in 2013 and soon thereafter refurbished with work that included powder-coating the frame, replacing the plastics, refreshing the air-cooled 430cc two-stroke single, overhauling the suspension, and more. It\u2026",
#             "url": "https://bringatrailer.com/listing/1983-husqvarna-430-wr/",
#             "urlToImage": "https://bringatrailer.com/wp-content/uploads/2025/01/1983_husqvarna_wr-430_img_48531-10350.jpg",
#             "publishedAt": "2025-02-06T16:35:09Z",
#             "content": "This 1983 Husqvarna 430 WR was acquired by the seller in 2013 and soon thereafter refurbished with work that included powder-coating the frame, replacing the plastics, refreshing the air-cooled 430cc\u2026 [+2093 chars]"
#         },
#         {
#             "source": {
#                 "id": null,
#                 "name": "The Punch"
#             },
#             "author": "Tosin Oyediran",
#             "title": "Lagos set for full enforcement of single-use plastics ban",
#             "description": "The Lagos State Government on Thursday hosted members of the Food and Beverages Recyclers Alliance on a courtesy visit to discuss the modalities for the enforcement of the ban on single-use plastics, emphasising that full enforcement will commence very soon. \u2026",
#             "url": "https://punchng.com/lagos-set-for-full-enforcement-of-single-use-plastics-ban/",
#             "urlToImage": "https://cdn.punchng.com/wp-content/uploads/2025/02/06162237/IMG-20250206-WA0019-1200x630.jpg",
#             "publishedAt": "2025-02-06T15:31:27Z",
#             "content": "The Lagos State Government on Thursday hosted members of the Food and Beverages Recyclers Alliance on a courtesy visit to discuss the modalities for the enforcement of the ban on single-use plastics,\u2026 [+4049 chars]"
#         },
#         {
#             "source": {
#                 "id": null,
#                 "name": "The Punch"
#             },
#             "author": "Gbenga Oloniniran",
#             "title": "LASG to enforce ban on single-use plastics",
#             "description": "The Lagos State Government on Thursday, stated that it had begun discussions on the enforcement of the ban on single-use plastics, insisting that the full enforcement will commence very soon. Speaking while hosting members of the Food and Beverages Recyclers \u2026",
#             "url": "https://punchng.com/lasg-to-enforce-ban-on-single-use-plastics/",
#             "urlToImage": "https://cdn.punchng.com/wp-content/uploads/2024/12/24110255/Tokunbo-Wahab-983x630.jpeg",
#             "publishedAt": "2025-02-07T00:50:32Z",
#             "content": "The Lagos State Government on Thursday, stated that it had begun discussions on the enforcement of the ban on single-use plastics, insisting that the full enforcement will commence very soon.\r\nSpeaki\u2026 [+1507 chars]"
#         },
#         {
#             "source": {
#                 "id": null,
#                 "name": "VOA News"
#             },
#             "author": "webdesk@voanews.com (VOA News)",
#             "title": "Back to plastic: Trump announces US policy \u2018to end the use of paper straws\u2019",
#             "description": "President Donald Trump issued an executive order Monday declaring that it is \u201cthe policy of the United States to end the use of paper straws.\u201d\n\n\nFormer President Joe Biden\u2019s administration, in an attempt to phase out federal purchases of single-use plastics, \u2026",
#             "url": "https://www.voanews.com/a/back-to-plastic-trump-announces-us-policy-to-end-the-use-of-paper-straws-/7970362.html",
#             "urlToImage": "https://gdb.voanews.com/6311761E-B087-4726-AF9A-69567EBF72AE.jpg",
#             "publishedAt": "2025-02-11T04:01:41Z",
#             "content": "President Donald Trump issued an executive order Monday declaring that it is the policy of the United States to end the use of paper straws.\r\nFormer President Joe Bidens administration, in an attempt\u2026 [+1221 chars]"
#         },
#         {
#             "source": {
#                 "id": null,
#                 "name": "New York Daily News"
#             },
#             "author": "Jessica Schladebeck, New York Daily News",
#             "title": "Trump vows to bring back plastic straws",
#             "description": "President Donald Trump has reached his final \u2014 paper \u2014 straw. In a social media post shared on his platform, Truth Social, Trump on Friday declared his...",
#             "url": "https://www.nydailynews.com/2025/02/07/trump-plastic-straws/",
#             "urlToImage": "https://s.yimg.com/ny/api/res/1.2/yG1O8wV5D9uFJoU8Eowgpw--/YXBwaWQ9aGlnaGxhbmRlcjt3PTEyMDA7aD03OTc-/https://media.zenfs.com/en/ny_daily_news_national_852/9e85c1de56d3ab0329e55c6300bb2f92",
#             "publishedAt": "2025-02-07T21:52:00Z",
#             "content": "President Donald Trump has reached his final paper straw.\r\nIn a social media post shared on his platform, Truth Social, Trump on Friday declared his intentions to rollback former President Joe Bidens\u2026 [+1265 chars]"
#         },
#         {
#             "source": {
#                 "id": null,
#                 "name": "Bringatrailer.com"
#             },
#             "author": "bringatrailer",
#             "title": "1979 Honda CR125R Elsinore at No Reserve",
#             "description": "This 1979 Honda CR125R Elsinore was acquired as a non-running project in 2008 by the seller, who subsequently carried out a refurbishment that was completed in October 2022. Work at that time included refinishing the bike in Tahitian red, repairing the expans\u2026",
#             "url": "https://bringatrailer.com/listing/1979-honda-cr125r-elsinore-2/",
#             "urlToImage": "https://bringatrailer.com/wp-content/uploads/2025/01/1979_honda_cr125r-elsinore_img_5058-10470.jpeg",
#             "publishedAt": "2025-01-29T21:50:03Z",
#             "content": "This 1979 Honda CR125R Elsinore was acquired as a non-running project in 2008 by the seller, who subsequently carried out a refurbishment that was completed in October 2022. Work at that time include\u2026 [+2144 chars]"
#         },
#         {
#             "source": {
#                 "id": null,
#                 "name": "The Star Online"
#             },
#             "author": "The Star Online",
#             "title": "No more free plastic bags in Penang from March 1",
#             "description": "GEORGE TOWN: Penang is stepping up its \u201cNo Plastic Bag\u201d campaign with no bags to be given out daily from March, as part of its commitment to environmental conservation and sustainability. Read full story",
#             "url": "https://www.thestar.com.my/news/nation/2025/02/15/no-more-free-plastic-bags-in-penang-from-march-1",
#             "urlToImage": "https://apicms.thestar.com.my/uploads/images/2025/02/15/3168601.jpg",
#             "publishedAt": "2025-02-14T23:00:00Z",
#             "content": "GEORGE TOWN: Penang is stepping up its No Plastic Bag campaign with no bags to be given out daily from March, as part of its commitment to environmental conservation and sustainability.\r\nState housin\u2026 [+1258 chars]"
#         },
#         {
#             "source": {
#                 "id": null,
#                 "name": "The Punch"
#             },
#             "author": "Arinze Nwafor",
#             "title": "Increased plastics recycling better than ban, MAN insists",
#             "description": "The Manufacturers Association of Nigeria has maintained that increased recycling capacity is a win-win situation for the country\u2019s economy rather than a ban on single-use plastics. The Director-General of MAN, Segun Ajayi-Kadir, told The PUNCH in a telephone \u2026",
#             "url": "https://punchng.com/increased-plastics-recycling-better-than-ban-man-insists/",
#             "urlToImage": "https://cdn.punchng.com/wp-content/uploads/2023/05/13211743/Ajayi-Kadir.jpg",
#             "publishedAt": "2025-02-14T00:10:32Z",
#             "content": "The Manufacturers Association of Nigeria has maintained that increased recycling capacity is a win-win situation for the countrys economy rather than a ban on single-use plastics.\r\nThe Director-Gener\u2026 [+2870 chars]"
#         },
#         {
#             "source": {
#                 "id": null,
#                 "name": "Bangkok Post"
#             },
#             "author": "Bangkok Post Public Company Limited",
#             "title": "Thai environmentalists upset as US revokes plastic straw ban",
#             "description": "Environmentalists in Thailand expressed their disappointment on Tuesday (February 11) after U.S. President Donald Trump signed an executive order to bring back plastic drinking straws, pushing back efforts by his predecessor to phase out single-use plastics a\u2026",
#             "url": "https://www.bangkokpost.com/video/world/2959533",
#             "urlToImage": "https://static.bangkokpost.com/media/content/20250212/c1_2959533_700.jpg",
#             "publishedAt": "2025-02-12T04:10:00Z",
#             "content": "Environmentalists in Thailand expressed their disappointment on Tuesday (February 11) after U.S. President Donald Trump signed an executive order to bring back plastic drinking straws, pushing back e\u2026 [+85 chars]"
#         },
#         {
#             "source": {
#                 "id": null,
#                 "name": "New York Post"
#             },
#             "author": "Diana Glebova",
#             "title": "Trump vows to end Biden\u2019s \u2018ridiculous\u2019 paper straw initiative: \u2018Back to plastic\u2019",
#             "description": "The Biden ban on single-use plastics applied to straws, cutlery and cups as well as packaging.",
#             "url": "https://nypost.com/2025/02/07/us-news/trump-vows-to-end-bidens-ridiculous-paper-straw-initiative-back-to-plastic/",
#             "urlToImage": "https://nypost.com/wp-content/uploads/sites/2/2025/02/2018-san-francisco-california-san-98062878.jpg?quality=75&strip=all&w=1024",
#             "publishedAt": "2025-02-07T18:40:34Z",
#             "content": "WASHINGTON President Trump announced Friday that he will soon sign an executive order ending the Biden administration\u2019s initiative to ban plastic straws across the federal government.\r\n\u201cI will be sig\u2026 [+2247 chars]"
#         },
#         {
#             "source": {
#                 "id": null,
#                 "name": "Yale.edu"
#             },
#             "author": null,
#             "title": "Microplastics Block Blood Flow in Brains of Mice",
#             "description": "A new study finds microplastics can block the flow of blood in the brains of mice. The study comes on the heels of other research showing, for the first time, that microplastics can lodge in human brains.Read more on E360 \u2192",
#             "url": "https://e360.yale.edu/digest/microplastics-brain-blood-mice",
#             "urlToImage": null,
#             "publishedAt": "2025-01-27T13:43:00Z",
#             "content": "A new study finds microplastics can block the flow of blood in the brains of mice. The study comes on the heels of other research showing, for the first time, that microplastics can lodge in human br\u2026 [+1402 chars]"
#         },
#         {
#             "source": {
#                 "id": null,
#                 "name": "Bringatrailer.com"
#             },
#             "author": "bringatrailer",
#             "title": "1979 Honda XR80 at No Reserve",
#             "description": "This 1979 Honda XR80 was reportedly placed in long-term storage by a Honda dealership in the Pacific Northwest when it shuttered its doors in the 1980s. The seller acquired it in 2019 and recommissioning work included tuning the carburetor, changing the oil, \u2026",
#             "url": "https://bringatrailer.com/listing/1979-honda-xr80-5/",
#             "urlToImage": "https://bringatrailer.com/wp-content/uploads/2025/01/1979_honda_xr80_p1015504-39744.jpg",
#             "publishedAt": "2025-01-17T23:55:03Z",
#             "content": "This 1979 Honda XR80 was reportedly placed in long-term storage by a Honda dealership in the Pacific Northwest when it shuttered its doors in the 1980s. The seller acquired it in 2019 and recommissio\u2026 [+1831 chars]"
#         },
#         {
#             "source": {
#                 "id": null,
#                 "name": "International Business Times"
#             },
#             "author": "Paavan MATHEMA",
#             "title": "Rubbish Roads: Nepal Explores Paving With Plastic",
#             "description": "Cars speeding along a smooth, black-coloured street in Nepal's Pokhara are also driving over heaps of discarded plastic, transformed into an ingredient in road construction.",
#             "url": "https://www.ibtimes.com/rubbish-roads-nepal-explores-paving-plastic-3760917",
#             "urlToImage": "https://d.ibtimes.com/en/full/4578228/vehicles-riding-over-road-built-using-recycled-plastic-waste-pokhara.jpg",
#             "publishedAt": "2025-01-25T07:21:21Z",
#             "content": "Cars speeding along a smooth, black-coloured street in Nepal's Pokhara are also driving over heaps of discarded plastic, transformed into an ingredient in road construction.\r\nNepal's urban areas gene\u2026 [+4012 chars]"
#         },
#         {
#             "source": {
#                 "id": "rt",
#                 "name": "RT"
#             },
#             "author": "RT",
#             "title": "Trump to reverse Biden\u2019s plastic straw ban",
#             "description": "President Trump has announced an order to bring back plastic straws, overturning the Biden administration\u2019s move towards paper alternatives Read Full Article at RT.com",
#             "url": "https://www.rt.com/news/612354-trump-plastic-paper-straws/",
#             "urlToImage": "https://mf.b37mrtl.ru/files/2025.02/article/67a64c202030273d917bb21f.jpg",
#             "publishedAt": "2025-02-07T18:29:07Z",
#             "content": "US President Donald Trump has promised to sign an executive order against paper straws next week. The move would reverse former President Joe Biden\u2019s plan to phase out single-use plastic products in \u2026 [+1522 chars]"
#         },
#         {
#             "source": {
#                 "id": "rt",
#                 "name": "RT"
#             },
#             "author": "RT",
#             "title": "\u2018It doesn\u2019t harm us\u2019: Russian scientist busts myths about microplastics",
#             "description": "Alarming media reports about the harm of microplastics to the human body and the environment are greatly exaggerated Read Full Article at RT.com",
#             "url": "https://www.rt.com/news/612723-alarming-media-reports-microplastics/",
#             "urlToImage": "https://mf.b37mrtl.ru/files/2025.02/article/67af4e7785f54030726e41d2.jpg",
#             "publishedAt": "2025-02-15T11:32:49Z",
#             "content": "Microplastics are among the most widely discussed environmental topics today. The media often highlights\u00a0the harmful effects of polymer nanoparticles on living organisms. However, as head of the Depa\u2026 [+5680 chars]"
#         },
#         {
#             "source": {
#                 "id": null,
#                 "name": "Sadanduseless.com"
#             },
#             "author": "A B",
#             "title": "Plastic Straws Memes: Trump Brings Back Plastic Straws",
#             "description": "Donald Trump has made the plastic straws great again by signing an executive order aimed at encouraging the US government and consumers to buy plastic drinking straws, pushing back efforts by his predecessor to phase out single-use plastics and tackle waste. \u2026",
#             "url": "https://www.sadanduseless.com/plastic-straws-memes/",
#             "urlToImage": "https://sadanduseless.b-cdn.net/wp-content/uploads/2025/02/plastic-straws-memes.png",
#             "publishedAt": "2025-02-11T19:26:59Z",
#             "content": "Donald Trump has made the plastic straws great again by signing an executive order aimed at encouraging the US government and consumers to buy plastic drinking straws, pushing back efforts by his pre\u2026 [+601 chars]"
#         },
#         {
#             "source": {
#                 "id": null,
#                 "name": "Aresluna.org"
#             },
#             "author": "Marcin Wichary",
#             "title": "The hardest working font in Manhattan",
#             "description": "A story of a 150-year-old font you have never heard of \u2013 and one you probably saw earlier today.",
#             "url": "https://aresluna.org/the-hardest-working-font-in-manhattan/",
#             "urlToImage": "https://aresluna.org/images/the-hardest-working-font-in-manhattan/ogimage.png",
#             "publishedAt": "2025-02-14T21:45:49Z",
#             "content": "Marcin Wichary\r\n14\u00a0February\u00a02025\u00a0/ 6,100\u00a0words\u00a0/ 600\u00a0photos\r\nIn 2007, on my first trip to New York City, I grabbed a brand-new DSLR camera and photographed all the fonts I was supposed to love. I adm\u2026 [+37821 chars]"
#         },
#         {
#             "source": {
#                 "id": null,
#                 "name": "TechSpot"
#             },
#             "author": "Kishalaya Kundu",
#             "title": "Repairing your Xbox just got a whole lot easier, thanks to Microsoft's new DIY program",
#             "description": "For those who prefer having their Xbox repaired by an authorized expert, Microsoft has partnered with uBreakiFix by Asurion to offer repair services at nearly 700 participating locations across the US. With this partnership, uBreakiFix becomes the first Xbox \u2026",
#             "url": "https://www.techspot.com/news/106376-repairing-xbox-got-whole-lot-easier-thanks-microsoft.html",
#             "urlToImage": "https://www.techspot.com/images2/news/bigimage/2025/01/2025-01-16-image-23.jpg",
#             "publishedAt": "2025-01-16T15:47:00Z",
#             "content": "Something to look forward to: Microsoft is making it easier than ever to repair Xbox consoles. Starting this month, the company is providing multiple repair options to accommodate all gamers whether \u2026 [+2322 chars]"
#         },
#         {
#             "source": {
#                 "id": null,
#                 "name": "BBC News"
#             },
#             "author": "BBC",
#             "title": "Women can buy Mooncups for \u00a35 through the council",
#             "description": "The authority says in one year, one Mooncup can replace 264 single-use menstrual products.",
#             "url": "https://www.bbc.com/news/articles/ce3ly47v25no?xtor=AL-72-%5Bpartner%5D-%5Byahoo.north.america%5D-%5Bheadline%5D-%5Bnews%5D-%5Bbizdev%5D-%5Bisapi%5D",
#             "urlToImage": "https://s.yimg.com/ny/api/res/1.2/OjhQXTGJPhJ43n06AGVvQg--/YXBwaWQ9aGlnaGxhbmRlcjt3PTEyMDA7aD02NzU-/https://media.zenfs.com/en/bbc_us_articles_995/af658bf7369e34bc2430d06bfd67c38e",
#             "publishedAt": "2025-01-28T06:29:21Z",
#             "content": "Women can buy a reusable period product at a discounted price as part of a council initiative to protect the environment.\r\nThe Mooncup programme is being funded by the Cambridgeshire and Peterborough\u2026 [+1722 chars]"
#         },
#         {
#             "source": {
#                 "id": null,
#                 "name": "mindbodygreen.com"
#             },
#             "author": "https://www.mindbodygreen.com/wc/eloisa-lewis",
#             "title": "5 Rituals That Will Boost Your Health & Help The Planet At The Same Time",
#             "description": "From growing your own food to gathering in community.",
#             "url": "https://www.mindbodygreen.com/articles/5-rituals-that-support-your-health-and-planet-at-same-time",
#             "urlToImage": "https://mindbodygreen-res.cloudinary.com/image/upload/c_fill,w_2000,h_1200,g_auto,fl_lossy,f_jpg/org/nt1nuzzkyl2hvhy4o.jpg",
#             "publishedAt": "2025-01-18T11:25:00Z",
#             "content": "This article was co-written by Mandalin Sattle.\r\nWe as humans are not separate from the rest of the species on Earth. Flora, fauna, prairies, streams... the cycles and patterns of our planet deeply a\u2026 [+4158 chars]"
#         },
#         {
#             "source": {
#                 "id": "new-york-magazine",
#                 "name": "New York Magazine"
#             },
#             "author": "Margaret Hartmann",
#             "title": "Is Trump\u2019s Paper-Straw Ban Really About His Shark Phobia?",
#             "description": "Is Trump\u2019s paper-straw ban really about his shark phobia? Trump signed a plastic-straw executive order and claimed it won\u2019t \u2018affect a shark very much.\u2019 But he once declared, \u2018I hope all the sharks die,\u2019 according to Stormy Daniels.",
#             "url": "http://nymag.com/intelligencer/article/trump-paper-straw-ban-plastic-shark.html",
#             "urlToImage": "https://pyxis.nymag.com/v1/imgs/c5a/d50/d0609b0488949ba7634ea1412eb1ef8653-shark-trump.1x.rsocial.w1200.jpg",
#             "publishedAt": "2025-02-11T21:24:33Z",
#             "content": "There are a lot of pressing national issues President Trump has yet to address, but he has weighed in on the slightly less urgent matter of paper straws. On Monday evening, Trump directed the federal\u2026 [+3743 chars]"
#         },
#         {
#             "source": {
#                 "id": null,
#                 "name": "Forbes"
#             },
#             "author": "Melissa Cristina Marquez, Contributor, \n Melissa Cristina Marquez, Contributor\n https://www.forbes.com/sites/melissacristinamarquez/",
#             "title": "Cigarette Butts Are A Hidden Threat To California\u2019s Horn Sharks",
#             "description": "In Southern California, the Marine Debris Tracker is providing insights into how waste affects species like the California horn shark.",
#             "url": "https://www.forbes.com/sites/melissacristinamarquez/2025/01/17/cigarette-butts-are-a-hidden-threat-to-californias-horn-sharks/",
#             "urlToImage": "https://imageio.forbes.com/specials-images/imageserve/67842c0abe51c9f369f611b9/0x0.jpg?format=jpg&height=900&width=1600&fit=bounds",
#             "publishedAt": "2025-01-17T12:00:00Z",
#             "content": "Currently, the California horn shark is listed as data deficient by the International Union for ... [+] Conservation of Nature (IUCN), which means there is not enough information to assess its conser\u2026 [+5984 chars]"
#         },
#         {
#             "source": {
#                 "id": null,
#                 "name": "Yahoo Entertainment"
#             },
#             "author": "The Guardian",
#             "title": "Trump to reverse Biden\u2019s plan to phase out plastic straws across US government",
#             "description": "President said he will sign an executive order next week despite global plastics crisis",
#             "url": "https://uk.news.yahoo.com/trump-reverse-biden-plan-phase-154116359.html",
#             "urlToImage": "https://media.zenfs.com/en/theguardian_763/baf177bbaa22fbf61b011eb5a3f636e4",
#             "publishedAt": "2025-02-08T15:41:16Z",
#             "content": "Donald Trump has said that he will reverse Joe Bidens plan to phase out plastic straws across the US government, complaining that paper alternatives dont work and that a move is needed to go BACK TO \u2026 [+3850 chars]"
#         },
#         {
#             "source": {
#                 "id": null,
#                 "name": "BBC News"
#             },
#             "author": "Kelvin Kimathi",
#             "title": "Rwanda and South Africa race to bring F1 back to Africa",
#             "description": "Rwanda and South Africa hope to host an African grand prix for the first time since 1993, but several expensive obstacles stand in their way.",
#             "url": "https://www.bbc.com/sport/formula1/articles/cq8k55exqvko",
#             "urlToImage": "https://ichef.bbci.co.uk/ace/branded_sport/1200/cpsprodpb/9947/live/8eaabd90-d8d6-11ef-902e-cf9b84dc1357.jpg",
#             "publishedAt": "2025-01-30T10:24:09Z",
# ...
#             "publishedAt": "2025-02-10T21:00:00Z",
#             "content": "The showstopper is the Ambassador Lagoon, an 11-million-liter open-water tank and the highlight of the Lost Chambers aquarium. (That\u2019s more literage than all of the tanks at California\u2019s famous Monte\u2026 [+8985 chars]"
#         },
#         {
#             "source": {
#                 "id": null,
#                 "name": "Lifesciencesworld.com"
#             },
#             "author": "LSW Team",
#             "title": "Are brita filters recyclable?",
#             "description": "Are Brita Filters Recyclable? Introduction Brita filters are a popular choice for removing impurities from water, making it safer for [\u2026]\nThe post Are brita filters recyclable? appeared first on Life Sciences World.",
#             "url": "https://lifesciencesworld.com/are-brita-filters-recyclable/",
#             "urlToImage": "https://lifesciencesworld.com/wp-content/uploads/2024/12/featured.png",
#             "publishedAt": "2025-02-02T10:20:10Z",
#             "content": "Are Brita Filters Recyclable?\r\nIntroduction\r\nBrita filters are a popular choice for removing impurities from water, making it safer for drinking. However, the recyclability of Brita filters is a topi\u2026 [+4193 chars]"
#         },
#         {
#             "source": {
#                 "id": null,
#                 "name": "Hospitality Net"
#             },
#             "author": "SOUMA Hotel Lima",
#             "title": "IHG debuts its first Vignette Collection hotel in South America \u2013 SOUMA Hotel Lima",
#             "description": "Vignette Collection, part of IHG Hotels & Resorts\u2019 luxury and lifestyle portfolio, welcomes SOUMA Hotel Lima in Peru as its first destination in South America. Vignette Collection, the newest brand in IHG\u2019s fast-growing luxury and lifestyle portfoli...",
#             "url": "https://www.hospitalitynet.org/announcement/41012118.html",
#             "urlToImage": "https://www.hospitalitynet.org/picture/social_153178589.jpg?t=1738688691",
#             "publishedAt": "2025-02-04T17:06:10Z",
#             "content": "Vignette Collection, part of IHG Hotels &amp; Resorts' luxury and lifestyle portfolio, welcomes SOUMA Hotel Lima in Peru as its first destination in South America. Vignette Collection, the newest bra\u2026 [+4822 chars]"
#         },
#         {
#             "source": {
#                 "id": null,
#                 "name": "Wattsupwiththat.com"
#             },
#             "author": "Guest Blogger",
#             "title": "MPs to Consider Bill Likely to Cause Mass Starvation, Death, Disease and Societal Collapse in Near Future",
#             "description": "A little science and realism might go a long way for supporters of a bill that seeks to ensure the end of the \u201cexploration, extraction, export and import of fossil fuels by the United Kingdom as rapidly as possible\u201d. Even the mad Miliband, the current Energy \u2026",
#             "url": "https://wattsupwiththat.com/2025/01/22/mps-to-consider-bill-likely-to-cause-mass-starvation-death-disease-and-societal-collapse-in-near-future/",
#             "urlToImage": "https://i0.wp.com/wattsupwiththat.com/wp-content/uploads/2025/01/53867021320_e8efa6caf7_k.webp?fit=1024%2C512&ssl=1",
#             "publishedAt": "2025-01-22T10:00:00Z",
#             "content": "From THE DAILY SCEPTIC\r\nby\u00a0Chris Morrison\r\nThis Friday, January 24th, the UK Parliament is due to vote on a Private Members Bill that could lead to mass starvation, widespread disease and fatalities \u2026 [+6992 chars]"
#         },
#         {
#             "source": {
#                 "id": "financial-post",
#                 "name": "Financial Post"
#             },
#             "author": "The Associated Press",
#             "title": "\u2018Back to plastic\u2019: Trump pushes for plastic straws as he declares paper ones \u2018don\u2019t work\u2019",
#             "description": "WASHINGTON (AP) \u2014 President Donald Trump is moving to reverse a federal push away from plastic straws, declaring that paper straws \u201cdon\u2019t work.\u201d Trump signed an executive order Monday, saying: \u201cIt\u2019s a ridiculous situation. We\u2019re going back to plastic straws\u201d \u2026",
#             "url": "https://financialpost.com/pmn/back-to-plastic-trump-pushes-for-plastic-straws-as-he-declares-paper-ones-dont-work",
#             "urlToImage": null,
#             "publishedAt": "2025-02-10T22:52:51Z",
#             "content": "Author of the article:\r\nArticle content\r\nWASHINGTON (AP) President Donald Trump is moving to reverse a federal push away from plastic straws, declaring that paper straws dont work.\r\nTrump signed an e\u2026 [+6958 chars]"
#         },
#         {
#             "source": {
#                 "id": null,
#                 "name": "ScienceAlert"
#             },
#             "author": "Theresa Larkin, The Conversation",
#             "title": "Sunlight Can Still Damage Skin Through a Closed Window. Here's How.",
#             "description": "When you're in a car, train or bus, do you choose a seat to avoid being in the sun or do you like the sunny side? You can definitely feel the sun's heat through a window.",
#             "url": "https://www.sciencealert.com/sunlight-can-still-damage-skin-through-a-closed-window-heres-how",
#             "urlToImage": "https://www.sciencealert.com/images/2025/02/man_driving_car_sunset_header.jpg",
#             "publishedAt": "2025-02-05T11:00:43Z",
#             "content": "When you're in a car, train or bus, do you choose a seat to avoid being in the sun or do you like the sunny side?\r\nYou can definitely feel the sun's heat through a window. But can you get sunburn or \u2026 [+5170 chars]"
#         },
#         {
#             "source": {
#                 "id": null,
#                 "name": "Digital Journal"
#             },
#             "author": "AFP",
#             "title": "Rubbish roads: Nepal explores paving with plastic",
#             "description": "Cars speeding along a smooth, black-coloured street in Nepal\u2019s Pokhara are also driving over heaps of discarded plastic, transformed into an ingredient in road construction. Nepal\u2019s urban areas generate about 5,000 tonnes of solid waste per day, according to \u2026",
#             "url": "https://www.digitaljournal.com/world/rubbish-roads-nepal-explores-paving-with-plastic/article",
#             "urlToImage": "https://www.digitaljournal.com/wp-content/uploads/2025/01/4f83050f836689acd89edb6072bf4aab4e4ce552.jpg",
#             "publishedAt": "2025-01-25T07:17:33Z",
#             "content": "Vehicles riding over a road built using recycled plastic waste in Pokhara - Copyright AFP Prakash MATHEMA\r\nCars speeding along a smooth, black-coloured street in Nepal\u2019s Pokhara are also driving over\u2026 [+4132 chars]"
#         },
#         {
#             "source": {
#                 "id": null,
#                 "name": "Lifesciencesworld.com"
#             },
#             "author": "LSW Team",
#             "title": "What is the toothpick thing?",
#             "description": "What is the Toothpick Thing? The toothpick thing, also known as a toothpick or a toothpick stick, is a small, [\u2026]\nThe post What is the toothpick thing? appeared first on Life Sciences World.",
#             "url": "https://lifesciencesworld.com/what-is-the-toothpick-thing/",
#             "urlToImage": "https://lifesciencesworld.com/wp-content/uploads/2024/12/featured.png",
#             "publishedAt": "2025-01-30T04:27:53Z",
#             "content": "What is the Toothpick Thing?\r\nThe toothpick thing, also known as a toothpick or a toothpick stick, is a small, thin, pointed tool used for cleaning between teeth and removing food particles. It is a \u2026 [+4942 chars]"
#         }
#     ]
# }
#
#  Guardian API JSON Response:
# {
#     "response": {
#         "status": "ok",
#         "userTier": "developer",
#         "total": 5720,
#         "startIndex": 1,
#         "pageSize": 10,
#         "currentPage": 1,
#         "pages": 572,
#         "orderBy": "relevance",
#         "results": [
#             {
#                 "id": "environment/2025/feb/17/reducing-plastic-use-is-possible-but-its-not-easy",
#                 "type": "article",
#                 "sectionId": "environment",
#                 "sectionName": "Environment",
#                 "webPublicationDate": "2025-02-17T17:04:42Z",
#                 "webTitle": "Reducing plastic use is possible, but it\u2019s not easy | Letters",
#                 "webUrl": "https://www.theguardian.com/environment/2025/feb/17/reducing-plastic-use-is-possible-but-its-not-easy",
#                 "apiUrl": "https://content.guardianapis.com/environment/2025/feb/17/reducing-plastic-use-is-possible-but-its-not-easy",
#                 "isHosted": false,
#                 "pillarId": "pillar/news",
#                 "pillarName": "News"
#             },
#             {
#                 "id": "environment/2024/nov/20/five-firms-in-plastic-pollution-alliance-made-1000-times-more-waste-than-they-saved-analysis-shows",
#                 "type": "article",
#                 "sectionId": "environment",
#                 "sectionName": "Environment",
#                 "webPublicationDate": "2024-11-20T10:00:02Z",
#                 "webTitle": "Five firms in plastic pollution alliance \u2018made 1,000 times more plastic than they cleaned up\u2019",
#                 "webUrl": "https://www.theguardian.com/environment/2024/nov/20/five-firms-in-plastic-pollution-alliance-made-1000-times-more-waste-than-they-saved-analysis-shows",
#                 "apiUrl": "https://content.guardianapis.com/environment/2024/nov/20/five-firms-in-plastic-pollution-alliance-made-1000-times-more-waste-than-they-saved-analysis-shows",
#                 "isHosted": false,
#                 "pillarId": "pillar/news",
#                 "pillarName": "News"
#             },
#             {
#                 "id": "environment/2024/nov/20/bali-plastic-recycling-scheme-swamped-with-garbage",
#                 "type": "article",
#                 "sectionId": "environment",
#                 "sectionName": "Environment",
#                 "webPublicationDate": "2024-11-20T10:00:03Z",
#                 "webTitle": "Bali plastic recycling scheme swamped with garbage",
#                 "webUrl": "https://www.theguardian.com/environment/2024/nov/20/bali-plastic-recycling-scheme-swamped-with-garbage",
#                 "apiUrl": "https://content.guardianapis.com/environment/2024/nov/20/bali-plastic-recycling-scheme-swamped-with-garbage",
#                 "isHosted": false,
#                 "pillarId": "pillar/news",
#                 "pillarName": "News"
#             },
#             {
#                 "id": "environment/2024/dec/23/we-need-to-ditch-plastic-lids-for-the-planet",
#                 "type": "article",
#                 "sectionId": "environment",
#                 "sectionName": "Environment",
#                 "webPublicationDate": "2024-12-23T17:14:41Z",
#                 "webTitle": "We need to ditch plastic lids for the planet | Letters",
#                 "webUrl": "https://www.theguardian.com/environment/2024/dec/23/we-need-to-ditch-plastic-lids-for-the-planet",
#                 "apiUrl": "https://content.guardianapis.com/environment/2024/dec/23/we-need-to-ditch-plastic-lids-for-the-planet",
#                 "isHosted": false,
#                 "pillarId": "pillar/news",
#                 "pillarName": "News"
#             },
#             {
#                 "id": "environment/2025/jan/07/thailand-bans-imports-plastic-waste-curb-toxic-pollution",
#                 "type": "article",
#                 "sectionId": "environment",
#                 "sectionName": "Environment",
#                 "webPublicationDate": "2025-01-07T14:05:25Z",
#                 "webTitle": "Thailand bans imports of plastic waste to curb toxic pollution",
#                 "webUrl": "https://www.theguardian.com/environment/2025/jan/07/thailand-bans-imports-plastic-waste-curb-toxic-pollution",
#                 "apiUrl": "https://content.guardianapis.com/environment/2025/jan/07/thailand-bans-imports-plastic-waste-curb-toxic-pollution",
#                 "isHosted": false,
#                 "pillarId": "pillar/news",
#                 "pillarName": "News"
#             },
#             {
#                 "id": "commentisfree/2025/feb/16/a-tale-of-two-suckers-donald-trumps-plastic-straws-and-keir-starmer",
#                 "type": "article",
#                 "sectionId": "commentisfree",
#                 "sectionName": "Opinion",
#                 "webPublicationDate": "2025-02-16T10:00:03Z",
#                 "webTitle": "A tale of two suckers: Donald Trump\u2019s plastic straws and Keir Starmer | Stewart Lee",
#                 "webUrl": "https://www.theguardian.com/commentisfree/2025/feb/16/a-tale-of-two-suckers-donald-trumps-plastic-straws-and-keir-starmer",
#                 "apiUrl": "https://content.guardianapis.com/commentisfree/2025/feb/16/a-tale-of-two-suckers-donald-trumps-plastic-straws-and-keir-starmer",
#                 "isHosted": false,
#                 "pillarId": "pillar/opinion",
#                 "pillarName": "Opinion"
#             },
#             {
#                 "id": "us-news/2025/feb/10/trump-plastic-straws-executive-order",
#                 "type": "article",
#                 "sectionId": "us-news",
#                 "sectionName": "US news",
#                 "webPublicationDate": "2025-02-11T02:47:54Z",
#                 "webTitle": "Trump signs order to bring back plastic straws, claiming paper ones \u2018explode\u2019",
#                 "webUrl": "https://www.theguardian.com/us-news/2025/feb/10/trump-plastic-straws-executive-order",
#                 "apiUrl": "https://content.guardianapis.com/us-news/2025/feb/10/trump-plastic-straws-executive-order",
#                 "isHosted": false,
#                 "pillarId": "pillar/news",
#                 "pillarName": "News"
#             },
#             {
#                 "id": "world/2025/jan/07/fda-phthalates-plastic-lawsuit",
#                 "type": "article",
#                 "sectionId": "world",
#                 "sectionName": "World news",
#                 "webPublicationDate": "2025-01-07T16:52:52Z",
#                 "webTitle": "Environmental groups sue FDA over refusal to tackle risky plastic packaging",
#                 "webUrl": "https://www.theguardian.com/world/2025/jan/07/fda-phthalates-plastic-lawsuit",
#                 "apiUrl": "https://content.guardianapis.com/world/2025/jan/07/fda-phthalates-plastic-lawsuit",
#                 "isHosted": false,
#                 "pillarId": "pillar/news",
#                 "pillarName": "News"
#             },
#             {
#                 "id": "environment/2025/jan/27/black-plastic-bad-six-things-to-know",
#                 "type": "article",
#                 "sectionId": "environment",
#                 "sectionName": "Environment",
#                 "webPublicationDate": "2025-01-27T15:00:00Z",
#                 "webTitle": "Is black plastic really bad for you? Six things you should know",
#                 "webUrl": "https://www.theguardian.com/environment/2025/jan/27/black-plastic-bad-six-things-to-know",
#                 "apiUrl": "https://content.guardianapis.com/environment/2025/jan/27/black-plastic-bad-six-things-to-know",
#                 "isHosted": false,
#                 "pillarId": "pillar/news",
#                 "pillarName": "News"
#             },
#             {
#                 "id": "us-news/2025/feb/08/trump-plastic-straws",
#                 "type": "article",
#                 "sectionId": "us-news",
#                 "sectionName": "US news",
#                 "webPublicationDate": "2025-02-08T15:41:16Z",
#                 "webTitle": "Trump to reverse Biden\u2019s plan to phase out plastic straws across US government",
#                 "webUrl": "https://www.theguardian.com/us-news/2025/feb/08/trump-plastic-straws",
#                 "apiUrl": "https://content.guardianapis.com/us-news/2025/feb/08/trump-plastic-straws",
#                 "isHosted": false,
#                 "pillarId": "pillar/news",
#                 "pillarName": "News"
#             }
#         ]
#     }
# }

# %%
print("\n Guardian API JSON Response:")
fetch_api_data(guardian_url)
# Out:
#  Guardian API JSON Response:
# {
#     "response": {
#         "status": "ok",
#         "userTier": "developer",
#         "total": 5720,
#         "startIndex": 1,
#         "pageSize": 10,
#         "currentPage": 1,
#         "pages": 572,
#         "orderBy": "relevance",
#         "results": [
#             {
#                 "id": "environment/2025/feb/17/reducing-plastic-use-is-possible-but-its-not-easy",
#                 "type": "article",
#                 "sectionId": "environment",
#                 "sectionName": "Environment",
#                 "webPublicationDate": "2025-02-17T17:04:42Z",
#                 "webTitle": "Reducing plastic use is possible, but it\u2019s not easy | Letters",
#                 "webUrl": "https://www.theguardian.com/environment/2025/feb/17/reducing-plastic-use-is-possible-but-its-not-easy",
#                 "apiUrl": "https://content.guardianapis.com/environment/2025/feb/17/reducing-plastic-use-is-possible-but-its-not-easy",
#                 "isHosted": false,
#                 "pillarId": "pillar/news",
#                 "pillarName": "News"
#             },
#             {
#                 "id": "environment/2024/nov/20/five-firms-in-plastic-pollution-alliance-made-1000-times-more-waste-than-they-saved-analysis-shows",
#                 "type": "article",
#                 "sectionId": "environment",
#                 "sectionName": "Environment",
#                 "webPublicationDate": "2024-11-20T10:00:02Z",
#                 "webTitle": "Five firms in plastic pollution alliance \u2018made 1,000 times more plastic than they cleaned up\u2019",
#                 "webUrl": "https://www.theguardian.com/environment/2024/nov/20/five-firms-in-plastic-pollution-alliance-made-1000-times-more-waste-than-they-saved-analysis-shows",
#                 "apiUrl": "https://content.guardianapis.com/environment/2024/nov/20/five-firms-in-plastic-pollution-alliance-made-1000-times-more-waste-than-they-saved-analysis-shows",
#                 "isHosted": false,
#                 "pillarId": "pillar/news",
#                 "pillarName": "News"
#             },
#             {
#                 "id": "environment/2024/nov/20/bali-plastic-recycling-scheme-swamped-with-garbage",
#                 "type": "article",
#                 "sectionId": "environment",
#                 "sectionName": "Environment",
#                 "webPublicationDate": "2024-11-20T10:00:03Z",
#                 "webTitle": "Bali plastic recycling scheme swamped with garbage",
#                 "webUrl": "https://www.theguardian.com/environment/2024/nov/20/bali-plastic-recycling-scheme-swamped-with-garbage",
#                 "apiUrl": "https://content.guardianapis.com/environment/2024/nov/20/bali-plastic-recycling-scheme-swamped-with-garbage",
#                 "isHosted": false,
#                 "pillarId": "pillar/news",
#                 "pillarName": "News"
#             },
#             {
#                 "id": "environment/2024/dec/23/we-need-to-ditch-plastic-lids-for-the-planet",
#                 "type": "article",
#                 "sectionId": "environment",
#                 "sectionName": "Environment",
#                 "webPublicationDate": "2024-12-23T17:14:41Z",
#                 "webTitle": "We need to ditch plastic lids for the planet | Letters",
#                 "webUrl": "https://www.theguardian.com/environment/2024/dec/23/we-need-to-ditch-plastic-lids-for-the-planet",
#                 "apiUrl": "https://content.guardianapis.com/environment/2024/dec/23/we-need-to-ditch-plastic-lids-for-the-planet",
#                 "isHosted": false,
#                 "pillarId": "pillar/news",
#                 "pillarName": "News"
#             },
#             {
#                 "id": "environment/2025/jan/07/thailand-bans-imports-plastic-waste-curb-toxic-pollution",
#                 "type": "article",
#                 "sectionId": "environment",
#                 "sectionName": "Environment",
#                 "webPublicationDate": "2025-01-07T14:05:25Z",
#                 "webTitle": "Thailand bans imports of plastic waste to curb toxic pollution",
#                 "webUrl": "https://www.theguardian.com/environment/2025/jan/07/thailand-bans-imports-plastic-waste-curb-toxic-pollution",
#                 "apiUrl": "https://content.guardianapis.com/environment/2025/jan/07/thailand-bans-imports-plastic-waste-curb-toxic-pollution",
#                 "isHosted": false,
#                 "pillarId": "pillar/news",
#                 "pillarName": "News"
#             },
#             {
#                 "id": "commentisfree/2025/feb/16/a-tale-of-two-suckers-donald-trumps-plastic-straws-and-keir-starmer",
#                 "type": "article",
#                 "sectionId": "commentisfree",
#                 "sectionName": "Opinion",
#                 "webPublicationDate": "2025-02-16T10:00:03Z",
#                 "webTitle": "A tale of two suckers: Donald Trump\u2019s plastic straws and Keir Starmer | Stewart Lee",
#                 "webUrl": "https://www.theguardian.com/commentisfree/2025/feb/16/a-tale-of-two-suckers-donald-trumps-plastic-straws-and-keir-starmer",
#                 "apiUrl": "https://content.guardianapis.com/commentisfree/2025/feb/16/a-tale-of-two-suckers-donald-trumps-plastic-straws-and-keir-starmer",
#                 "isHosted": false,
#                 "pillarId": "pillar/opinion",
#                 "pillarName": "Opinion"
#             },
#             {
#                 "id": "us-news/2025/feb/10/trump-plastic-straws-executive-order",
#                 "type": "article",
#                 "sectionId": "us-news",
#                 "sectionName": "US news",
#                 "webPublicationDate": "2025-02-11T02:47:54Z",
#                 "webTitle": "Trump signs order to bring back plastic straws, claiming paper ones \u2018explode\u2019",
#                 "webUrl": "https://www.theguardian.com/us-news/2025/feb/10/trump-plastic-straws-executive-order",
#                 "apiUrl": "https://content.guardianapis.com/us-news/2025/feb/10/trump-plastic-straws-executive-order",
#                 "isHosted": false,
#                 "pillarId": "pillar/news",
#                 "pillarName": "News"
#             },
#             {
#                 "id": "world/2025/jan/07/fda-phthalates-plastic-lawsuit",
#                 "type": "article",
#                 "sectionId": "world",
#                 "sectionName": "World news",
#                 "webPublicationDate": "2025-01-07T16:52:52Z",
#                 "webTitle": "Environmental groups sue FDA over refusal to tackle risky plastic packaging",
#                 "webUrl": "https://www.theguardian.com/world/2025/jan/07/fda-phthalates-plastic-lawsuit",
#                 "apiUrl": "https://content.guardianapis.com/world/2025/jan/07/fda-phthalates-plastic-lawsuit",
#                 "isHosted": false,
#                 "pillarId": "pillar/news",
#                 "pillarName": "News"
#             },
#             {
#                 "id": "environment/2025/jan/27/black-plastic-bad-six-things-to-know",
#                 "type": "article",
#                 "sectionId": "environment",
#                 "sectionName": "Environment",
#                 "webPublicationDate": "2025-01-27T15:00:00Z",
#                 "webTitle": "Is black plastic really bad for you? Six things you should know",
#                 "webUrl": "https://www.theguardian.com/environment/2025/jan/27/black-plastic-bad-six-things-to-know",
#                 "apiUrl": "https://content.guardianapis.com/environment/2025/jan/27/black-plastic-bad-six-things-to-know",
#                 "isHosted": false,
#                 "pillarId": "pillar/news",
#                 "pillarName": "News"
#             },
#             {
#                 "id": "us-news/2025/feb/08/trump-plastic-straws",
#                 "type": "article",
#                 "sectionId": "us-news",
#                 "sectionName": "US news",
#                 "webPublicationDate": "2025-02-08T15:41:16Z",
#                 "webTitle": "Trump to reverse Biden\u2019s plan to phase out plastic straws across US government",
#                 "webUrl": "https://www.theguardian.com/us-news/2025/feb/08/trump-plastic-straws",
#                 "apiUrl": "https://content.guardianapis.com/us-news/2025/feb/08/trump-plastic-straws",
#                 "isHosted": false,
#                 "pillarId": "pillar/news",
#                 "pillarName": "News"
#             }
#         ]
#     }
# }
